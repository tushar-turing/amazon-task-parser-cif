# %%
import json
import nbformat
import os

def get_cell_text(cell):
    """Safely join multiline or string cell contents."""
    return ''.join(cell['source']) if isinstance(cell['source'], list) else cell['source']

def is_user_cell(cell):
    return cell['cell_type'] == 'markdown' and '**[user]**' in get_cell_text(cell)

def is_assistant_cell(cell):
    return cell['cell_type'] == 'markdown' and '**[assistant]**' in get_cell_text(cell)

def is_metadata_cell(cell):
    return cell['cell_type'] == 'markdown' and '**[turn_metadata]**' in get_cell_text(cell)

def extract_json_from_metadata_cell(source_text):
    try:
        start = source_text.find("```")
        end = source_text.rfind("```")
        if start == -1 or end == -1 or start == end:
            return {}
        json_str = source_text[start+3:end].strip()
        return json.loads(json_str)
    except json.JSONDecodeError as e:
        print("⚠️ JSON decode error:", e)
        return {}

def process_notebook(file_path, dialogue_id=None):
    with open(file_path, "r", encoding="utf-8") as f:
        nb = nbformat.read(f, as_version=4)

    turns = []
    cells = nb['cells']
    i = 0

    while i < len(cells) - 2:
        user_cell = cells[i]
        print(user_cell)
        metadata_cell = cells[i + 1]    
        print(metadata_cell)
        assistant_cell = cells[i + 2]
        print(assistant_cell)

        print(is_user_cell(user_cell))
        print(is_assistant_cell(assistant_cell))
        print(is_metadata_cell(metadata_cell))

        if is_user_cell(user_cell) and is_assistant_cell(assistant_cell) and is_metadata_cell(metadata_cell):
            prompt = get_cell_text(user_cell).replace('**[user]**', '').strip()
            response = get_cell_text(assistant_cell).replace('**[assistant]**', '').strip()
            metadata_text = get_cell_text(metadata_cell)
            instruction_data = extract_json_from_metadata_cell(metadata_text)
            print(instruction_data)
            print(prompt)
            print(response)
            print(metadata_text)

            turns.append({
                "prompt": prompt,
                "response": response,
                "instructions": [
                    {
                        "instruction_id_list": instruction_data.get("instruction_id_list", []),
                        "kwargs": instruction_data.get("kwargs", [])
                    }
                ]
            })

            i += 3  # Advance to next triplet
        else:
            i += 1  # Skip malformed or extra cells

    return {
        "turns": turns,
        "dialogue_metadata": {
            "id": dialogue_id or os.path.basename(file_path),
            "length": len(turns)
        }
    }

# %%
markdown_sample = process_notebook('./samples/sample-1.ipynb')
# Out:
# {'cell_type': 'markdown', 'source': '**[user]**\n\n\nGenerate a comprehensive system diagnostic report from the following raw log entries.  \n- Begin with Report Start: and end with Report End.  \n- Use “###” to separate at least 4 distinct sections (e.g., Overview, Metrics, Warnings, Conclusions).  \n- Capitalize the first letter of the word “error” for each sentence.  \n- Mention the word “system” at least 3 times.  \n- Do not use any commas.  \n- The entire output must be under 1,000 characters.  \n- Wrap the whole report in double quotation marks.  \n\nRaw logs:\n\n\\[2025-05-16 08:15:23] INFO: System boot sequence initiated  \n\\[2025-05-16 08:15:24] WARN: Minor latency detected in module A  \n\\[2025-05-16 08:15:25] ERROR: Unexpected shutdown in module B  \n\\[2025-05-16 08:15:26] INFO: System reboot successful  \n\\[2025-05-16 08:15:27] ERROR: Disk read timeout in module C  \n\\[2025-05-16 08:15:28] INFO: All modules running within normal parameters\n', 'metadata': {'id': 'NpN9-DEcgejN'}}
# {'cell_type': 'markdown', 'source': '**[turn_metadata]**\n\n```\n{\n  "instruction_id_list": [\n    "startend:start_checker",\n    "startend:end_checker",\n    "detectable_format:multiple_sections",\n    "change_case:first_letter_cap_target",\n    "keywords:frequency",\n    "punctuation:no_comma",\n    "length_constraints:number_characters",\n    "startend:quotation"\n  ],\n  "kwargs": [\n    {\n      "start_phrase": "Report Start:"\n    },\n    {\n      "end_phrase": "Report End."\n    },\n    {\n      "section_splitter": "###",\n      "relation": "at least",\n      "num_sections": 4\n    },\n    {\n      "target_string": "error"\n    },\n    {\n      "keyword": "system",\n      "relation": "at least",\n      "frequency": 3\n    },\n    {\n      "relation": "less than",\n      "num_chars": 1000\n    }\n  ]\n}\n```', 'metadata': {'id': '83XNTJZMkvy0'}}
# {'cell_type': 'markdown', 'source': '**[assistant]**\n\n"Report Start:\n\n### Overview\n\nThe system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.\n\n### Metrics\n\nThe system booted and rebooted successfully\nLatency detected in module A\nTwo Error entries recorded\nThe system stabilized within seconds\n\n### Warnings\n\nOne warning issued for latency in module A\nTwo Error reports logged including an unexpected shutdown in module B and a disk read timeout in module C\n\n### Conclusions\n\nThe system experienced temporary faults but maintained core functionality. Quick reboot ensured continuity. Monitoring advised due to repeated Error events. System stability appears restored.\n\nReport End."', 'metadata': {'id': 'yRjyz9LLj3Yo'}}
# True
# True
# True
# {'instruction_id_list': ['startend:start_checker', 'startend:end_checker', 'detectable_format:multiple_sections', 'change_case:first_letter_cap_target', 'keywords:frequency', 'punctuation:no_comma', 'length_constraints:number_characters', 'startend:quotation'], 'kwargs': [{'start_phrase': 'Report Start:'}, {'end_phrase': 'Report End.'}, {'section_splitter': '###', 'relation': 'at least', 'num_sections': 4}, {'target_string': 'error'}, {'keyword': 'system', 'relation': 'at least', 'frequency': 3}, {'relation': 'less than', 'num_chars': 1000}]}
# Generate a comprehensive system diagnostic report from the following raw log entries.
# - Begin with Report Start: and end with Report End.
# - Use “###” to separate at least 4 distinct sections (e.g., Overview, Metrics, Warnings, Conclusions).
# - Capitalize the first letter of the word “error” for each sentence.
# - Mention the word “system” at least 3 times.
# - Do not use any commas.
# - The entire output must be under 1,000 characters.
# - Wrap the whole report in double quotation marks.
#
# Raw logs:
#
# \[2025-05-16 08:15:23] INFO: System boot sequence initiated
# \[2025-05-16 08:15:24] WARN: Minor latency detected in module A
# \[2025-05-16 08:15:25] ERROR: Unexpected shutdown in module B
# \[2025-05-16 08:15:26] INFO: System reboot successful
# \[2025-05-16 08:15:27] ERROR: Disk read timeout in module C
# \[2025-05-16 08:15:28] INFO: All modules running within normal parameters
# "Report Start:
#
# ### Overview
#
# The system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.
#
# ### Metrics
#
# The system booted and rebooted successfully
# Latency detected in module A
# Two Error entries recorded
# The system stabilized within seconds
#
# ### Warnings
#
# One warning issued for latency in module A
# Two Error reports logged including an unexpected shutdown in module B and a disk read timeout in module C
#
# ### Conclusions
#
# The system experienced temporary faults but maintained core functionality. Quick reboot ensured continuity. Monitoring advised due to repeated Error events. System stability appears restored.
#
# Report End."
# **[turn_metadata]**
#
# ```
# {
#   "instruction_id_list": [
#     "startend:start_checker",
#     "startend:end_checker",
#     "detectable_format:multiple_sections",
#     "change_case:first_letter_cap_target",
#     "keywords:frequency",
#     "punctuation:no_comma",
#     "length_constraints:number_characters",
#     "startend:quotation"
#   ],
#   "kwargs": [
#     {
#       "start_phrase": "Report Start:"
#     },
#     {
#       "end_phrase": "Report End."
#     },
#     {
#       "section_splitter": "###",
#       "relation": "at least",
#       "num_sections": 4
#     },
#     {
#       "target_string": "error"
#     },
#     {
#       "keyword": "system",
#       "relation": "at least",
#       "frequency": 3
#     },
#     {
#       "relation": "less than",
#       "num_chars": 1000
#     }
#   ]
# }
# ```
# {'cell_type': 'markdown', 'source': '**[user]**\n\nRewrite the diagnostic report above as a numbered list of exactly four items. Each item should begin with the section title (Overview, Metrics, Warnings, Conclusions) followed by its content. Preserve all existing constraints (capitalize only the first letter of each “error”, use no commas, wrap the entire output in quotation marks, and keep Report Start: at the top and Report End at the bottom).', 'metadata': {'id': 'smmvUOp1pUFN'}}
# {'cell_type': 'markdown', 'source': '**[turn_metadata]**\n\n```\n{\n  "instruction_id_list": [\n    "startend:start_checker",\n    "startend:end_checker",\n    "detectable_format:numbered_list",\n    "change_case:first_letter_cap_target",\n    "keywords:frequency",\n    "punctuation:no_comma",\n    "length_constraints:number_characters",\n    "startend:quotation"\n  ],\n  "kwargs": [\n    {\n      "start_phrase": "Report Start:"\n    },\n    {\n      "end_phrase": "Report End"\n    },\n    {\n      "relation": "equal to",\n      "num_numbered_items": 4\n    },\n    {\n      "target_string": "error"\n    },\n    {\n      "keyword": "system",\n      "relation": "at least",\n      "frequency": 3\n    },\n    {\n      "relation": "less than",\n      "num_chars": 1000\n    }\n  ]\n}\n\n```', 'metadata': {'id': 'Rr4O_QXvkhA1'}}
# {'cell_type': 'markdown', 'source': '**[assistant]**\n\n"Report Start:\n\n1. Overview: The system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.\n2. Metrics: System booted and rebooted successfully. Latency detected in module A. Two Error entries recorded. System stabilized within seconds.\n3. Warnings: One warning issued for latency in module A. Two Error reports logged including an unexpected shutdown in module B and a disk read timeout in module C.\n4. Conclusions: The system experienced temporary faults but maintained core functionality. Quick reboot ensured continuity. Monitoring advised due to repeated Error events. System stability appears restored.  \n\nReport End"\n', 'metadata': {'id': 'v_IbIFJLkhDt'}}
# True
# True
# True
# {'instruction_id_list': ['startend:start_checker', 'startend:end_checker', 'detectable_format:numbered_list', 'change_case:first_letter_cap_target', 'keywords:frequency', 'punctuation:no_comma', 'length_constraints:number_characters', 'startend:quotation'], 'kwargs': [{'start_phrase': 'Report Start:'}, {'end_phrase': 'Report End'}, {'relation': 'equal to', 'num_numbered_items': 4}, {'target_string': 'error'}, {'keyword': 'system', 'relation': 'at least', 'frequency': 3}, {'relation': 'less than', 'num_chars': 1000}]}
# Rewrite the diagnostic report above as a numbered list of exactly four items. Each item should begin with the section title (Overview, Metrics, Warnings, Conclusions) followed by its content. Preserve all existing constraints (capitalize only the first letter of each “error”, use no commas, wrap the entire output in quotation marks, and keep Report Start: at the top and Report End at the bottom).
# "Report Start:
#
# 1. Overview: The system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.
# 2. Metrics: System booted and rebooted successfully. Latency detected in module A. Two Error entries recorded. System stabilized within seconds.
# 3. Warnings: One warning issued for latency in module A. Two Error reports logged including an unexpected shutdown in module B and a disk read timeout in module C.
# 4. Conclusions: The system experienced temporary faults but maintained core functionality. Quick reboot ensured continuity. Monitoring advised due to repeated Error events. System stability appears restored.
#
# Report End"
# **[turn_metadata]**
#
# ```
# {
#   "instruction_id_list": [
#     "startend:start_checker",
#     "startend:end_checker",
#     "detectable_format:numbered_list",
#     "change_case:first_letter_cap_target",
#     "keywords:frequency",
#     "punctuation:no_comma",
#     "length_constraints:number_characters",
#     "startend:quotation"
#   ],
#   "kwargs": [
#     {
#       "start_phrase": "Report Start:"
#     },
#     {
#       "end_phrase": "Report End"
#     },
#     {
#       "relation": "equal to",
#       "num_numbered_items": 4
#     },
#     {
#       "target_string": "error"
#     },
#     {
#       "keyword": "system",
#       "relation": "at least",
#       "frequency": 3
#     },
#     {
#       "relation": "less than",
#       "num_chars": 1000
#     }
#   ]
# }
#
# ```
# {'cell_type': 'markdown', 'source': '**[user]**\n\nRewrite the diagnostic report above as a Markdown document wrapped in ```markdown fences. Use ## to separate exactly four sections—Overview, Metrics, Warnings, Conclusions. Under each section, include at least two bullet points summarizing its content. Apply alternating case to every occurrence of “system.”(start with upper-case) Append a postscript denoted by PS: at the end. Ensure the letter “S” appears at least four times across the document. Do not use the word “error.” Avoid any commas. Keep the total word count (do not count if the word contains only special characters) under 150.', 'metadata': {'id': 'nsDCNGrdr9kt'}}
# {'cell_type': 'markdown', 'source': '**[turn_metadata]**\n\n```\n{\n  "instruction_id_list": [\n    "detectable_format:multiple_sections",\n    "change_case:alternating_target",\n    "detectable_content:postscript",\n    "keywords:letter_frequency",\n    "keywords:forbidden_words",\n    "punctuation:no_comma",\n    "length_constraints:number_words"\n  ],\n  "kwargs": [\n    {\n      "section_splitter": "##",\n      "relation": "equal to",\n      "num_sections": 4\n    },\n    {\n      "target_string": "system"\n    },\n    {\n      "postscript_marker": "PS:"\n    },\n    {\n      "letter": "S",\n      "let_relation": "at least",\n      "let_frequency": 4\n    },\n    {\n      "forbidden_words": ["error"]\n    },\n    {\n      "relation": "less than",\n      "num_words": 150\n    }\n  ]\n}\n```', 'metadata': {'id': 'YU6917NPkhGV'}}
# {'cell_type': 'markdown', 'source': '**[assistant]**\n\n```markdown\n## Overview  \n- The SyStEm began its boot sequence at 08:15:23 on 2025-05-16  \n- Initial operations appeared normal with minor delays  \n\n## Metrics  \n- SyStEm rebooted successfully and resumed function  \n- Latency noted in module A and read timeout in module C  \n\n## Warnings  \n- One warning for latency in module A  \n- Unexpected shutdown detected in module B  \n\n## Conclusions  \n- The SyStEm recovered quickly and continued operation  \n- Further monitoring suggested due to past shutdown  \n\nPS: SyStEm shows signs of resilience despite slight issues\n```', 'metadata': {'id': 'S5DhT7vMkhJE'}}
# True
# True
# True
# {'instruction_id_list': ['detectable_format:multiple_sections', 'change_case:alternating_target', 'detectable_content:postscript', 'keywords:letter_frequency', 'keywords:forbidden_words', 'punctuation:no_comma', 'length_constraints:number_words'], 'kwargs': [{'section_splitter': '##', 'relation': 'equal to', 'num_sections': 4}, {'target_string': 'system'}, {'postscript_marker': 'PS:'}, {'letter': 'S', 'let_relation': 'at least', 'let_frequency': 4}, {'forbidden_words': ['error']}, {'relation': 'less than', 'num_words': 150}]}
# Rewrite the diagnostic report above as a Markdown document wrapped in ```markdown fences. Use ## to separate exactly four sections—Overview, Metrics, Warnings, Conclusions. Under each section, include at least two bullet points summarizing its content. Apply alternating case to every occurrence of “system.”(start with upper-case) Append a postscript denoted by PS: at the end. Ensure the letter “S” appears at least four times across the document. Do not use the word “error.” Avoid any commas. Keep the total word count (do not count if the word contains only special characters) under 150.
# ```markdown
# ## Overview
# - The SyStEm began its boot sequence at 08:15:23 on 2025-05-16
# - Initial operations appeared normal with minor delays
#
# ## Metrics
# - SyStEm rebooted successfully and resumed function
# - Latency noted in module A and read timeout in module C
#
# ## Warnings
# - One warning for latency in module A
# - Unexpected shutdown detected in module B
#
# ## Conclusions
# - The SyStEm recovered quickly and continued operation
# - Further monitoring suggested due to past shutdown
#
# PS: SyStEm shows signs of resilience despite slight issues
# ```
# **[turn_metadata]**
#
# ```
# {
#   "instruction_id_list": [
#     "detectable_format:multiple_sections",
#     "change_case:alternating_target",
#     "detectable_content:postscript",
#     "keywords:letter_frequency",
#     "keywords:forbidden_words",
#     "punctuation:no_comma",
#     "length_constraints:number_words"
#   ],
#   "kwargs": [
#     {
#       "section_splitter": "##",
#       "relation": "equal to",
#       "num_sections": 4
#     },
#     {
#       "target_string": "system"
#     },
#     {
#       "postscript_marker": "PS:"
#     },
#     {
#       "letter": "S",
#       "let_relation": "at least",
#       "let_frequency": 4
#     },
#     {
#       "forbidden_words": ["error"]
#     },
#     {
#       "relation": "less than",
#       "num_words": 150
#     }
#   ]
# }
# ```

# %%
markdown_sample
# Out:
# {'turns': [{'prompt': 'Generate a comprehensive system diagnostic report from the following raw log entries.  \n- Begin with Report Start: and end with Report End.  \n- Use “###” to separate at least 4 distinct sections (e.g., Overview, Metrics, Warnings, Conclusions).  \n- Capitalize the first letter of the word “error” for each sentence.  \n- Mention the word “system” at least 3 times.  \n- Do not use any commas.  \n- The entire output must be under 1,000 characters.  \n- Wrap the whole report in double quotation marks.  \n\nRaw logs:\n\n\\[2025-05-16 08:15:23] INFO: System boot sequence initiated  \n\\[2025-05-16 08:15:24] WARN: Minor latency detected in module A  \n\\[2025-05-16 08:15:25] ERROR: Unexpected shutdown in module B  \n\\[2025-05-16 08:15:26] INFO: System reboot successful  \n\\[2025-05-16 08:15:27] ERROR: Disk read timeout in module C  \n\\[2025-05-16 08:15:28] INFO: All modules running within normal parameters',
#    'response': '"Report Start:\n\n### Overview\n\nThe system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.\n\n### Metrics\n\nThe system booted and rebooted successfully\nLatency detected in module A\nTwo Error entries recorded\nThe system stabilized within seconds\n\n### Warnings\n\nOne warning issued for latency in module A\nTwo Error reports logged including an unexpected shutdown in module B and a disk read timeout in module C\n\n### Conclusions\n\nThe system experienced temporary faults but maintained core functionality. Quick reboot ensured continuity. Monitoring advised due to repeated Error events. System stability appears restored.\n\nReport End."',
#    'instructions': [{'instruction_id_list': ['startend:start_checker',
#       'startend:end_checker',
#       'detectable_format:multiple_sections',
#       'change_case:first_letter_cap_target',
#       'keywords:frequency',
#       'punctuation:no_comma',
#       'length_constraints:number_characters',
#       'startend:quotation'],
#      'kwargs': [{'start_phrase': 'Report Start:'},
#       {'end_phrase': 'Report End.'},
#       {'section_splitter': '###', 'relation': 'at least', 'num_sections': 4},
#       {'target_string': 'error'},
#       {'keyword': 'system', 'relation': 'at least', 'frequency': 3},
#       {'relation': 'less than', 'num_chars': 1000}]}]},
#   {'prompt': 'Rewrite the diagnostic report above as a numbered list of exactly four items. Each item should begin with the section title (Overview, Metrics, Warnings, Conclusions) followed by its content. Preserve all existing constraints (capitalize only the first letter of each “error”, use no commas, wrap the entire output in quotation marks, and keep Report Start: at the top and Report End at the bottom).',
#    'response': '"Report Start:\n\n1. Overview: The system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.\n2. Metrics: System booted and rebooted successfully. Latency detected in module A. Two Error entries recorded. System stabilized within seconds.\n3. Warnings: One warning issued for latency in module A. Two Error reports logged including an unexpected shutdown in module B and a disk read timeout in module C.\n4. Conclusions: The system experienced temporary faults but maintained core functionality. Quick reboot ensured continuity. Monitoring advised due to repeated Error events. System stability appears restored.  \n\nReport End"',
#    'instructions': [{'instruction_id_list': ['startend:start_checker',
#       'startend:end_checker',
#       'detectable_format:numbered_list',
#       'change_case:first_letter_cap_target',
#       'keywords:frequency',
#       'punctuation:no_comma',
#       'length_constraints:number_characters',
#       'startend:quotation'],
#      'kwargs': [{'start_phrase': 'Report Start:'},
#       {'end_phrase': 'Report End'},
#       {'relation': 'equal to', 'num_numbered_items': 4},
#       {'target_string': 'error'},
#       {'keyword': 'system', 'relation': 'at least', 'frequency': 3},
#       {'relation': 'less than', 'num_chars': 1000}]}]},
#   {'prompt': 'Rewrite the diagnostic report above as a Markdown document wrapped in ```markdown fences. Use ## to separate exactly four sections—Overview, Metrics, Warnings, Conclusions. Under each section, include at least two bullet points summarizing its content. Apply alternating case to every occurrence of “system.”(start with upper-case) Append a postscript denoted by PS: at the end. Ensure the letter “S” appears at least four times across the document. Do not use the word “error.” Avoid any commas. Keep the total word count (do not count if the word contains only special characters) under 150.',
#    'response': '```markdown\n## Overview  \n- The SyStEm began its boot sequence at 08:15:23 on 2025-05-16  \n- Initial operations appeared normal with minor delays  \n\n## Metrics  \n- SyStEm rebooted successfully and resumed function  \n- Latency noted in module A and read timeout in module C  \n\n## Warnings  \n- One warning for latency in module A  \n- Unexpected shutdown detected in module B  \n\n## Conclusions  \n- The SyStEm recovered quickly and continued operation  \n- Further monitoring suggested due to past shutdown  \n\nPS: SyStEm shows signs of resilience despite slight issues\n```',
#    'instructions': [{'instruction_id_list': ['detectable_format:multiple_sections',
#       'change_case:alternating_target',
#       'detectable_content:postscript',
#       'keywords:letter_frequency',
#       'keywords:forbidden_words',
#       'punctuation:no_comma',
#       'length_constraints:number_words'],
#      'kwargs': [{'section_splitter': '##',
#        'relation': 'equal to',
#        'num_sections': 4},
#       {'target_string': 'system'},
#       {'postscript_marker': 'PS:'},
#       {'letter': 'S', 'let_relation': 'at least', 'let_frequency': 4},
#       {'forbidden_words': ['error']},
#       {'relation': 'less than', 'num_words': 150}]}]}],
#  'dialogue_metadata': {'id': 'sample-1.ipynb', 'length': 3}}

# %%
import nbformat

with open("samples/sample-1.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

for i, cell in enumerate(nb['cells']):
    if cell['cell_type'] == 'markdown':
        print(f"\n--- Cell {i} ---")
        print("".join(cell['source'])[:300])  # Print first 300 characters
# Out:
# --- Cell 0 ---
# **[user]**
#
#
# Generate a comprehensive system diagnostic report from the following raw log entries.
# - Begin with Report Start: and end with Report End.
# - Use “###” to separate at least 4 distinct sections (e.g., Overview, Metrics, Warnings, Conclusions).
# - Capitalize the first letter of the wor
#
# --- Cell 1 ---
# **[turn_metadata]**
#
# ```
# {
#   "instruction_id_list": [
#     "startend:start_checker",
#     "startend:end_checker",
#     "detectable_format:multiple_sections",
#     "change_case:first_letter_cap_target",
#     "keywords:frequency",
#     "punctuation:no_comma",
#     "length_constraints:number_characters",
#
#
# --- Cell 2 ---
# **[assistant]**
#
# "Report Start:
#
# ### Overview
#
# The system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.
#
# ### Metrics
#
# The system booted and rebooted successfully
# Latency detected in module A
# Two Er
#
# --- Cell 3 ---
# **[user]**
#
# Rewrite the diagnostic report above as a numbered list of exactly four items. Each item should begin with the section title (Overview, Metrics, Warnings, Conclusions) followed by its content. Preserve all existing constraints (capitalize only the first letter of each “error”, use no comm
#
# --- Cell 4 ---
# **[turn_metadata]**
#
# ```
# {
#   "instruction_id_list": [
#     "startend:start_checker",
#     "startend:end_checker",
#     "detectable_format:numbered_list",
#     "change_case:first_letter_cap_target",
#     "keywords:frequency",
#     "punctuation:no_comma",
#     "length_constraints:number_characters",
#     "sta
#
# --- Cell 5 ---
# **[assistant]**
#
# "Report Start:
#
# 1. Overview: The system began its boot sequence at 08:15:23 on 2025-05-16. Initial operations showed standard activity. A minor issue appeared early but recovery was rapid.
# 2. Metrics: System booted and rebooted successfully. Latency detected in module A. Two Error e
#
# --- Cell 6 ---
# **[user]**
#
# Rewrite the diagnostic report above as a Markdown document wrapped in ```markdown fences. Use ## to separate exactly four sections—Overview, Metrics, Warnings, Conclusions. Under each section, include at least two bullet points summarizing its content. Apply alternating case to every occ
#
# --- Cell 7 ---
# **[turn_metadata]**
#
# ```
# {
#   "instruction_id_list": [
#     "detectable_format:multiple_sections",
#     "change_case:alternating_target",
#     "detectable_content:postscript",
#     "keywords:letter_frequency",
#     "keywords:forbidden_words",
#     "punctuation:no_comma",
#     "length_constraints:number_word
#
# --- Cell 8 ---
# **[assistant]**
#
# ```markdown
# ## Overview
# - The SyStEm began its boot sequence at 08:15:23 on 2025-05-16
# - Initial operations appeared normal with minor delays
#
# ## Metrics
# - SyStEm rebooted successfully and resumed function
# - Latency noted in module A and read timeout in module C
#
# ## Warn
#
# --- Cell 9 ---
# **[incorrect-assistant]**
#
# ```
# ### Overview
# - The System began its boot sequence at 08:15:23 on 2025-05-16
# - Initial operations appeared normal with slight delay
#
# ### Metrics
# - System rebooted successfully and resumed function
# - Latency noted in module A and disk read timeout in module C
